# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Numbers ##

# %%
# int

# %%
# float

# %%
# float

# %%
# float

# %%
# 2 raised to the power of one-half

# %%
# The square root of 2 raised to the power of 2

# %%
# Importing Math module

# %%
# the square root of 2 raised to the power of 2

# %%
123456 ** 780

# %%
382764238764.238792034876503865238723985

# %%
382764238764.238792034876503865238723985 - 382764238764.2388

# %%
# scientific notation
243559489848374254236.454985738

# %%
# scientific notation
402/35426520405030403

# %% [markdown]
# ## Strings ##

# %%
# string

# %%
# The line below has an error. Why?

Flavor

# %%
# The line below has an error. Why?

"Flavor'

# %%
# A string can contain a space. 

'Vanilla Flavor'

# %%
# A string can represent a number. 

'234'

# %%
# The line below has an error. 

'Don't put apstrophes in a string'

# %%
# Correct the line above.

# %%
# If a string contains double quotation marks, enclose the string in single quotes.

'you can have "quotation" marks'

# %%
# A name can be assigned to a string.

# %%
# Strings can be concatenated.

# %%
# Strings can be concatenated.

# %%
# Strings can be concatenated.

# %%
# The line below has an error. 

hi 'students'

# %%
# To combine a name and a string, we use the + operator.

# %%
x = 'straw'
y = 'berry'
x + y

# %%
# A string can be multiplied to an integer. 

'ha' * 10

# %%
# How about this? 

'ha' * 'ha'

# %%
# You can’t add strings and integers together

'I have ' + 10 + ' dollars in my pocket.'

# %% [markdown]
# ## Conversions ##

# %%
# Convert the string '100' to the integer 100.

# %%
# Convert the string '23.45' to the float 23.45.

# %%
# How about this? 

float('23')

# %%
# The line below has an error. Why? 

int('23.45')

# %%
# Convert the integer 10 into the string '10'.

# %%
# Convert the integer 17 into the float 17.0.

# %%
# How about this? 

int(123.90)

# %%
# Convert the string '3.0' to the integer 3.

# %%
'12' + '1.2'

# %%
# String Method: Replace          

"hitchhiker".replace('hi', 'ma')

# %%
s = "train"
t = s.replace('t', 'ing')   # this will be ingrain
u = t.replace('in', 'de')   # this will be degrade   
u

# %% [markdown]
# ## Types ##

# %%
# Find the type of the number 10.

# %%
a = 10
type(a)

# %%
# Find the type of the number 4.5.

# %%
# Find the type of the number 10/2.

# %%
# Find the type of 'hello'.

# %%
# Find the type of max.

# %%
# Find the type of True.

# %% [markdown]
# ## Arrays ##

# %%
# We can get a particular item in an array.
# Syntax: array_name.item(index) 
# Get the first item in the array, second_four.

# %%
# Get the second item in the array, second_four.
