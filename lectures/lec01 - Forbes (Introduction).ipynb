# %% [markdown]
# **Note:** In this lecture there is a lot of code. You are not expected to know any of this yet. This is just a preview of the things you will see in the next few weeks.

# %% [markdown]
# ## This is a Jupyter Notebook
#
# A Jupyter Notebook is a data-science environment that combines:
#
# 1. **Narrative:** The text describing your analysis
# 2. **Code:** The program that does the analysis
# 3. **Results:** The output of the program
#
# The Jupyter environment was created by faculty at UC Berkeley (Fernando Perez). These ideas are now in a lot of different technologies (e.g., Google Collab).

# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

# %%
# "Adventures of Huckleberry Finn" (by Mark Twain) 

huck_finn_url = 'https://www.inferentialthinking.com/data/huck_finn.txt'
huck_finn_text = read_url(huck_finn_url)
huck_finn_chapters = huck_finn_text.split('CHAPTER ')[44:]

# "Little Women" (by Louisa May Alcott)

little_women_url = 'https://www.inferentialthinking.com/data/little_women.txt'
little_women_text = read_url(little_women_url)
little_women_chapters = little_women_text.split('CHAPTER ')[1:]

# %%
huck_finn_chapters

# %%
# Chapters of Huckleberry Finn in Table format

...

# %%
# How many times Tom appears in each chapter. 

np.char.count(huck_finn_chapters, 'Tom')

# %%
# How many times Jim appears in each chapter. 

...

# %%
# How many times each person appears in each chapter. 

counts = Table().with_columns([
    'Tom', np.char.count(huck_finn_chapters, 'Tom'),
    'Jim', np.char.count(huck_finn_chapters, 'Jim'),
    'Huck', np.char.count(huck_finn_chapters, 'Huck'),
])
counts

# %%
# Get cumulative counts (how many times in Chapter 1, how many times in Chapters 1 and 2, and so on) for each character and add to table.

cum_counts = Table().with_column('Chapter', np.arange(1, 44, 1))
for character_name in counts.labels:
    cum_counts = cum_counts.with_column(character_name,np.cumsum(counts.column(character_name)))

# Plot cumulative counts.

cum_counts.plot(column_for_xticks='Chapter')
plots.title('Cumulative Number of Times Name Appears');

# %%
# Chapters of Little Women in Table format

Table().with_column('Chapters', little_women_chapters)

# %%
# Counts of names in the chapters of Little Women

names = ['Amy', 'Beth', 'Jo', 'Laurie', 'Meg']
mentions = {name: np.char.count(little_women_chapters, name) for name in names}

counts = Table().with_columns([
        'Amy', mentions['Amy'],
        'Beth', mentions['Beth'],
        'Jo', mentions['Jo'],
        'Laurie', mentions['Laurie'],
        'Meg', mentions['Meg']
    ])
counts

# %%
# Get cumulative counts for each character and add to table

cum_counts = Table().with_column('Chapter', np.arange(1, 48, 1))
for character_name in counts.labels:
    cum_counts = cum_counts.with_column(character_name,np.cumsum(counts.column(character_name)))

# Visualize cumulative counts

cum_counts.plot(column_for_xticks='Chapter')
plots.title('Cumulative Number of Times Name Appears');

# %%
# Number of characters in text

...

# %%
# The number of characters in the entire book of Huckleberry Finn

len(huck_finn_text)

# %%
# In each chapter, count the number of all characters;
# call this the "length" of the chapter.
# Also count the number of periods.

length_hf = Table().with_columns([
        'Length', [len(s) for s in huck_finn_chapters],
        'Periods', np.char.count(huck_finn_chapters, '.')
    ])
length_lw = Table().with_columns([
        'Length', [len(s) for s in little_women_chapters],
        'Periods', np.char.count(little_women_chapters, '.')
    ])

# %%
# The counts for Huckleberry Finn

length_hf

# %%
# The counts for Little Women

length_lw

# %%
plots.figure(figsize=(10,10))
plots.scatter(length_hf[1], length_hf[0], color='darkblue')
plots.scatter(length_lw[1], length_lw[0], color='gold')
plots.xlabel('Number of periods in chapter')
plots.ylabel('Number of characters in chapter');
