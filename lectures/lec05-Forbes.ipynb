# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
# Read the table of NBA salaries dataset. 

nba = ...('nba_salaries.csv')
nba

# %%
# Sort the nba table by season in descending order.

# %%
# Select only the rows for the 2020 season from the nba table. 
# Then drop the season column. 
# Then show the top 5 athletes in terms of their salaries.

# %%
nba

# %%
# Find the number of rows of the nba table.

# %%
# Find the number of columns of the nba table.

# %%
# List the nba table’s column labels.

# %%
# Selecting the 100th row from the nba table.

# %%
# Select the 2nd, 6th, and 10th rows from the nba table.

# %%
# Select only the rows for the Golden State Warriors from the nba table. 
# Then assign the new table to the name, warriors. 
# Finally, show the first 5 rows.

# %%
# Change the column label 'salary' to '$' in the warriors table.

# %%
# Select only the rows for the Golden State Warriors from the nba table.
# Then drop the team column. 
# Then relabel 'salary' as '$'.
# Then assign the new table to the name, warriors. 
# Finally, show the first 3 rows.

# %%
# Extract the $ column from the warriors table as an array.

# %%
# Create a copy of the warriors table containing only the '$' column.

# %%
# Calculate the total sum of all the values in the '$' column of the warriors table.

# %%
# The line below will cause an error. Why? 

np.sum(warriors.select('$'))

# %%
# Calculate the average of all the values in the '$' column of the warriors table.

# %%
# An alternate method to calculate the average

# %%
# Write an expression that selects only the rows for the Phoneix Suns from the nba table.
# Then drop the team column. 
# Then relabel 'salary' to '$'.
# Then assign the new table to the name, suns. 
# Fially, show the first 7 rows.

# %%
# Calculate the average of all the values in the '$' column of the suns table.

# %%
# Find the difference between the average salary of the Warriors and that of the Suns.

# %%
# We can also use the len function to find the number of rows of the warriors table.

# %%
# We can also use the len function to find the number of columns of the warriors table.

# %%
# Write an expression that returns LeBron James's salary for the season 2019 using the nba table.

# %% [markdown]
# Ok. Let's go back to the lecture notes.

# %% [markdown]
# ## Ranges ##

# %%
np.arange(5)

# %%
np.arange(10.2)

# %% [markdown]
# np.arange(0, 20)

# %%
np.arange(0, 20, 2)

# %%
np.arange(1, 15, 2.5)

# %%
np.arange(20, 4, -2)

# %%
# Selecting the first 10 rows of the nba table.

# %%
nba.show(10)

# %%
# Select five rows starting from row 6 (6th row) of the nba table.

# %%
# Find the average salary of the five highest-paid players for the Warriors.

# %% [markdown]
# ## Creating a Table from Scratch ##

# %%
streets = make_array('Crenshaw', 'Van Ness', 'Western', 'Normandie')

# %%
# Adding a column to an empty table.

# %%
# Adding a column to the eastside table.

# %%
# Adding two columns to an empty table.

Table().with_columns( 
    "Street", streets, 
    "Blocks from campus", np.arange(4)
)

# %%
# Adding a column with a recurring value.

# %%
# Adding a row to the eastside table.

# %%
# Creating an empty table with a label row (column headers).
# Then adding the first row (Crenshaw).

Table(['Streets', 'Blocks from campus']).with_rows([['Crenshaw',0],['Van Ness', 2]])

# %% [markdown]
# ## Table.where Predicates

# %%
warriors

# %%
# Selecting rows where the salary is greater than $10 million.

# %%
# Select rows where the salary is less than or equal to $2 million.

# %%
# Select rows where the position contains the letter "G".

# %%
# From the nba table, select the rows where the position is a point guard (PG).
# Assign the new table to the name guards.
# Then, using the guards table, create an array containing the names of all point guards (PG) who made more than $15M.

# %%
# Do not run this cell until you answer the question below. 
# After these two lines are run, what value does nba.num_columns return, and why?

nba.drop('position')
nba.num_columns
