# %%
# Import Packages 

from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Table Review: Data 8 Welcome Survey

# %%
# Read in UC Berkeley DATA8 student survey data.
welcome = Table.read_table('welcome_survey_sp22.csv')
welcome.show(10)

# %%
# On average, how long do side-sleepers sleep?

# %%
# Create a table that includes only the students who sleep on their back or stomach.

# %%
# How many students get at least 8 hours of sleep each night?

# %%
# Create a table with only 'Hours of sleep' and 'Sleep position' columns.
# Then assign the table to the name, two_col.
# Then relabel 'Hours of sleep' as 'Hours' and 'Sleep position' as 'Position'.
# Then assign the table to the name, sleep.
# Then show the first three rows.

# %% [markdown]
# ## Census ##

# %%
# Read in Census Data. 

full = Table.read_table('nc-est2019-agesex-res.csv')
full.show()

# %%
# Make a new table that contains the following four columns:
# SEX, AGE, POPESTIMATE2014, and POPESTIMATE2019.
# Then assign the new table to the name partial.
# Then show the top 5 rows. 

partial = full...
partial...

# %%
# Relabel POPESTIMATE2014 as 2014 and POPESTIMATE2019 as 2019. 
# Then assign the new table to the name us_pop.
# Then show the top 5 rows.

us_pop = partial...
us_pop...

# %%
# Select all rows that have the value 0 in the SEX column. 
# Then drop the SEX column. 
# Assign the table to the name us_pop_by_age.

us_pop_by_age = us_pop...
us_pop_by_age

# %%
# Create an array containing the differences between the 2019 and 2014 population estimates for each age group.
# Then assign the array to the name change. 
# Add a column to the us_pop_by_age. Use the column label, Change, and the array, change.
# Then assign the table to the name us_pop_change and show the entire table.

change = ...  
us_pop_change = ...
us_pop_change.show()

# %% [markdown]
# ## 2019 Sex Ratios

# %%
us_pop_2019 = us_pop.drop('2014')
us_pop_2019.show(3)

# %%
all_ages = us_pop_2019.where('AGE', are.equal_to(999))
all_ages

# %%
# Add a column named Proportion to the all_ages table that contains 
# the population proportions for each SEX category.

pop_prop_2019 =...
all_ages.with_column('Proportion', pop_prop_2019)

# %%
females_all_rows = us_pop_2019.where('SEX', are.equal_to(2))
females = females_all_rows.where('AGE', are.not_equal_to(999))
females.show(3)

# %%
males_all_rows = us_pop_2019.where('SEX', are.equal_to(1))
males = males_all_rows.where('AGE', are.not_equal_to(999))
males.show(3)

# %%
# Create an array of the ratios of the female population to the male population at each age group in 2019.
# Then assign the array to the name f_to_m_ratios.
# Then create a table of two columns: Age and F:M Ratio.
# Then assign the table to the name ratios. 

f_to_m_ratios = ...
ratios = Table().with_columns(
    ...
    ...
)
ratios

# %%
# Sort the ratios table in descending order by age and show the entire table.

# %% [markdown]
# ## Line Plot

# %%
ratios.plot('Age', 'F:M Ratio')
