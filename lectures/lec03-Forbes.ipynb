# %%
# Addition

# %%
# Subtraction

# %%
# Multiplication

# %%
# Division

# %%
# The line below has an error.
* 4

# %%
# The line below has an error. 
2 * * 4

# %%
# Exponentiation

# %%
# Evaluate the expression.
2 + 3 * -5

# %%
# Evaluate the expression.

# %%
# Evaluate the expression.

# %%
# Evaluate the expression.
-(1 + 1) + 2 * (3 * 4 * 5 / 6) ** 3 + 7 + 8 + 9

# %%
'Hello.'

# %%
# Only the result of the last expression is shown as output.

# %%
# The print() function is used to display output.

# %% [markdown]
# ## Names ##

# %%
a = 2

# %%
# The line below causes a name error. Why? 
b

# %%
a = 4
b = 7 
total = a + b
total

# %%
a = 10

# %%
total

# %%
a

# %%
total = a + b
total

# %%
# The line below causes a syntax error.
a+b = total

# %%
a

# %%
a = a + 1
a

# %%
# We can assign a string to a name.

# %% [markdown]
# ### Why Names?

# %% [markdown]
# A cell with arithmetic but no names is difficult to interpret.

# %% [markdown]
# #### Option 1 (No variable names)

# %%
40 * 16.90

# %%
40 * 52 * 16.90

# %% [markdown]
# #### Option 2 (Using variable names)
# California’s state minimum wage for 2026 is $16.90.

# %%
ca_hourly_minimum_wage = ...                                              
hours_per_week = ...
weeks_per_year = ...

# %%
weekly_wages = ...                    
weekly_wages

# %%
hours_per_year = ...
hours_per_year

# %%
yearly_wages = ...
yearly_wages

# %% [markdown]
# ## Functions and Call Expressions

# %%
# Call the max function on 15 and 27.

# %%
# Call the min function on 34, 32, 56, 35, and 23.

# %%
# Call the absolute value function on -5.

# %%
# Absolute value of an expression
abs(1 - 3)

# %%
# Find the absolute value of the difference between the daytime and nighttime temperatures.
day_temp = 52
night_temp = 47
...

# %%
# Rounding a number to the nearest integer
round(123.456)

# %%
# Rounding a number to the nearest tenth
round(123.456, 1)

# %%
# You can also write like this! 
round(123.456, ndigits=1)

# %%
# How about this??
round(123.456, ndigits=-1)

# %%
# Forgot how to use the round function? Let's look at the documentation for the function!

# %%
sqrt(4)

# %%
# Computing the floor of 13.7.

# %%
# Computing the ceiling of 13.2.

# %%
# Calculating the logarithm of 16 in base 2.

# %%
# Looking up functions in the math module. 
# Type "math." Then press the Tab key.

# %% [markdown]
# ## Tables

# %%
# Importing the data science package

# %% [markdown]
# ### **Read** : Reading a table from a data file

# %%
# Reading a table

# %% [markdown]
# ### **Show**: Display a table with a specified number of rows

# %%
# Showing only the top few rows

# %%
# Forgot how to use the show function? Let's look at the documentation for the function!

# %%
# Showing the entire table

# %% [markdown]
# ### **Select**: Choosing columns

# %%
# Selecting only the Flavor column

# %%
# The line below has an error.   
cones.select(Flavor)

# %%
# The line below has an error.        
cones.select('flavor')

# %%
# Select the Flavor and Price columns.

# %% [markdown]
# ### **Drop**: Dropping columns

# %%
# Dropping the Color column

# %%
cones

# %%
# Assigning a name to the cones table without the Price column

# %% [markdown]
# ### **Where**: Selecting Rows that Satisfy a Condition

# %%
# Selecting the strawberry flavor rows of the cones table

# %%
# Drop the Price column from the previous table.

# %%
# We can also select the strawberry flavor rows of the cones_without_price table.

# %% [markdown]
# ### **Sort**: Sorting Rows

# %%
# Sorting the cones table by price in ascending order

# %%
# Sorting the cones table by price in descending order

# %%
# After sorting, we can keep only the first occurrence of each unique value in the sorted column (Price).

# %%
# Sort the cones table by flavor in descending order.

# %% [markdown]
# ### A more interesting table

# %%
# From https://github.com/erikgregorywebb/datasets/blob/master/nba-salaries.csv
# Read the NBA salaries table. 
nba = ... ('nba_salaries.csv')
nba

# %%
# Show the entire table.

# %%
# Create a table with just the point guards in the 2020 season and assign it to the variable name, point_guards.
point_guards = ...
point_guards

# %%
# Select the name, team, and salary columns from the point_guards table. 
# Then assign the new table to the variable name, point_guards. 

point_guards = ...
point_guards

# %%
# Sort the point_guards table in ascending order.
# Then show the first 15 rows.

# %%
# The line below will cause a value error. Why? 
nba.drop('position').where('position', 'PG')
